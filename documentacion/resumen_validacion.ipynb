# %% [markdown]
# # RESUMEN DE VALIDACIÓN - DATA WAREHOUSE
#
# **Fecha:** 2026-06-30
# **Responsables:** Belén Raura, Mateo Coronado, Edison Quizhpe, Liam Zúñiga
#
# ---
#
# ## Resumen Ejecutivo
#
# El proceso de carga, validación y cálculo de KPIs del Data Warehouse se ejecutó correctamente.
# Los controles de integridad, calidad y duplicados devolvieron resultados esperados en cero anomalías.
#
# **Conclusión general:** el Data Warehouse está consistente, confiable y listo para uso analítico.

# %% [markdown]
# ---
#
# ## 1. Integridad Referencial
#
# | Validación | Huérfanos | Estado |
# |------------|-----------|--------|
# | DimJuego → Hecho_Ventas | 0 | ✅ |
# | DimTiempo → Hecho_Ventas | 0 | ✅ |
# | DimCliente → Hecho_Ventas | 0 | ✅ |

# %% [markdown]
# ---
#
# ## 2. Calidad de Datos
#
# | Prueba | Resultado | Estado |
# |--------|-----------|--------|
# | Precios Negativos | 0 | ✅ |
# | Cantidades Negativas | 0 | ✅ |
# | Fechas Inválidas | 0 | ✅ |
# | Totales Incorrectos | 0 | ✅ |

# %% [markdown]
# ---
#
# ## 3. Duplicados
#
# | Tabla | Registros | Duplicados |
# |-------|-----------|------------|
# | DimJuego | 47,051 | 0 |
# | DimTiempo | 9,132 | 0 |
# | DimCliente | 100 | 0 |
# | Hecho_Ventas | 10,050 | 0 |

# %% [markdown]
# ---
#
# ## 4. KPIs Validados
#
# | KPI | Valor | Comparación |
# |-----|-------|-------------|
# | Ventas Totales visibles en el corte de 12 meses | $57,252.83 | Validado contra salida del script |
# | Ticket Promedio | $135.39 | 100% exacto |
# | Clientes Activos | 100 | 100% exacto |
# | Total de juegos en catálogo | 47,051 | Coincide con la carga |
# | Total de ventas registradas | 10,050 | Coincide con la carga |

# %% [markdown]
# ---
#
# ## 5. Evidencia Visual
#
# ### Dashboard principal
#
# ![Dashboard principal](../capturas/dashboard_principal.png)
#
# ### Evolución de ventas por tiempo
#
# ![Ventas por tiempo](../capturas/dashboard_tiempo.png)
#
# ### Top productos
#
# ![Top juegos](../capturas/dashboard_top_juegos.png)
#
# ### Distribución geográfica
#
# ![Distribución geográfica](../capturas/dashboard_geografico.png)
#
# ### Análisis por publisher
#
# ![Análisis por publisher](../capturas/dashboard_publisher.png)

# %% [markdown]
# ---
#
# ## 6. Evidencia de Ejecución
#
# Los logs completos de la corrida están disponibles en:
#
# - [Carga del DW](logs/carga_dw.log)
# - [Pruebas de consistencia](logs/pruebas_consistencia.log)
# - [KPIs](logs/kpis_validacion.log)
# - [Dashboard](logs/dashboard.log)
#
# La bitácora resumida de la ejecución está en [bitacora_carga.txt](bitacora_carga.txt).

# %% [markdown]
# ---
#
# ## Conclusión
#
# La implementación del Data Warehouse se completó con éxito, cumpliendo las etapas de carga de datos, validación de KPIs y pruebas de calidad. Los resultados evidencian que la información es confiable y no presenta problemas de integridad, duplicados ni inconsistencias. Además, el dashboard interactivo facilita la visualización de los indicadores principales y apoya la toma de decisiones.
